# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig_3_data = pd.read_csv("../data/fig_3_data_fugue_scores_for_six_tissues.csv")

# %%
fig_3_data = fig_3_data[["Tissue", "Description", "ZScore", "MeanExp", "Breadth", 
                        "CV", "NeighborMeanBreadth", "NeighborMeanZscore", "Label", "Probability"]]

# %%
fig_3_data = fig_3_data.dropna()

# %%
fig_3_data
# Out:
#      Tissue Description    ZScore      MeanExp   Breadth        CV  \
# 0     Heart        SDHA  1.993528   243.288498  0.846690  0.579540
# 1     Heart       TNNT2  3.955485  2449.070800  1.000000  0.458229
# 2     Heart       ACTN2  1.199822   507.696777  0.997677  0.604202
# 3     Heart       SCN5A  3.606891    38.107166  0.997677  0.631969
# 4     Heart        MYH6  3.016343  2784.512700  0.997677  1.017318
# ..      ...         ...       ...          ...       ...       ...
# 505  Testis      NANOS1 -0.306643     1.460238  0.279778  0.302469
# 506  Testis      HOXB13 -0.105192     0.194483  0.997230  0.522857
# 507  Testis    CATSPER2  4.448299    24.798389  1.000000  0.325885
# 508  Testis        CFTR -0.067128     1.729463  1.000000  0.270751
# 509  Testis        MSMB -0.072487    11.811653  1.000000  0.651447
#
#      NeighborMeanBreadth  NeighborMeanZscore Label  Probability
# 0               0.264830           -0.377133     P     0.985383
# ...

# %%
heart_df = fig_3_data[fig_3_data["Tissue"] == "Heart"]
breast_df = fig_3_data[fig_3_data["Tissue"] == "Breast"]
lung_df = fig_3_data[fig_3_data["Tissue"] == "Lung"]
muscle_df = fig_3_data[fig_3_data["Tissue"] == "Muscle"]
ovary_df = fig_3_data[fig_3_data["Tissue"] == "Ovary"]
testis_df = fig_3_data[fig_3_data["Tissue"] == "Testis"]

# %%
heart_df
# Out:
#     Tissue Description    ZScore      MeanExp   Breadth        CV  \
# 0    Heart        SDHA  1.993528   243.288498  0.846690  0.579540
# 1    Heart       TNNT2  3.955485  2449.070800  1.000000  0.458229
# 2    Heart       ACTN2  1.199822   507.696777  0.997677  0.604202
# 3    Heart       SCN5A  3.606891    38.107166  0.997677  0.631969
# 4    Heart        MYH6  3.016343  2784.512700  0.997677  1.017318
# ..     ...         ...       ...          ...       ...       ...
# 174  Heart       CENPF -0.264521     0.177311  0.091754  2.474792
# 175  Heart       SCN3B -0.379961     0.736151  0.041812  0.754590
# 176  Heart       KCNE2 -0.129869     0.256806  0.070848  1.264871
# 177  Heart      SLC6A2 -0.306395     0.009481  0.046458  2.197773
# 178  Heart        EGFR -0.841011     4.491855  0.003484  0.577752
#
#      NeighborMeanBreadth  NeighborMeanZscore Label  Probability
# 0               0.264830           -0.377133     P     0.985383
# ...

# %%
heart_df['default_rank'] = heart_df['Probability'].rank()
heart_df['pct_rank'] = heart_df['Probability'].rank(pct=True)
# Out:
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/1988708836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_df['default_rank'] = heart_df['Probability'].rank()
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/1988708836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_df['pct_rank'] = heart_df['Probability'].rank(pct=True)

# %%
breast_df['default_rank'] = breast_df['Probability'].rank()
breast_df['pct_rank'] = breast_df['Probability'].rank(pct=True)
# Out:
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/996380738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   breast_df['default_rank'] = breast_df['Probability'].rank()
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/996380738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   breast_df['pct_rank'] = breast_df['Probability'].rank(pct=True)

# %%
lung_df['default_rank'] = lung_df['Probability'].rank()
lung_df['pct_rank'] = lung_df['Probability'].rank(pct=True)
# Out:
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/3024882513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lung_df['default_rank'] = lung_df['Probability'].rank()
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/3024882513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lung_df['pct_rank'] = lung_df['Probability'].rank(pct=True)

# %%
muscle_df['default_rank'] = muscle_df['Probability'].rank()
muscle_df['pct_rank'] = muscle_df['Probability'].rank(pct=True)
# Out:
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/3662616951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   muscle_df['default_rank'] = muscle_df['Probability'].rank()
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/3662616951.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   muscle_df['pct_rank'] = muscle_df['Probability'].rank(pct=True)

# %%
ovary_df['default_rank'] = ovary_df['Probability'].rank()
ovary_df['pct_rank'] = ovary_df['Probability'].rank(pct=True)
# Out:
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/2908082236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ovary_df['default_rank'] = ovary_df['Probability'].rank()
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/2908082236.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ovary_df['pct_rank'] = ovary_df['Probability'].rank(pct=True)

# %%
testis_df['default_rank'] = testis_df['Probability'].rank()
testis_df['pct_rank'] = testis_df['Probability'].rank(pct=True)
# Out:
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/3021781547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testis_df['default_rank'] = testis_df['Probability'].rank()
# /var/folders/tq/wj2ck3214v37qskdmvyxhncw0000gn/T/ipykernel_96805/3021781547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testis_df['pct_rank'] = testis_df['Probability'].rank(pct=True)

# %% [markdown]
# ok now i want to mask and only take the data when label = p
# then i want to put alll of that info together

# %%
p_heart_df = heart_df[heart_df["Label"] == "P"]
p_breast_df = breast_df[breast_df["Label"] == "P"]
p_lung_df = lung_df[lung_df["Label"] == "P"]
p_muscle_df = muscle_df[muscle_df["Label"] == "P"]
p_ovary_df = ovary_df[ovary_df["Label"] == "P"]
p_testis_df = testis_df[testis_df["Label"] == "P"]

# %%
#tried doing N or U and P instead of just P
# p_heart_df = heart_df[heart_df["Label"] == "N"]
# p_breast_df = breast_df[breast_df["Label"] == "N"]
# p_lung_df = lung_df[lung_df["Label"] == "N"]
# p_muscle_df = muscle_df[muscle_df["Label"] == "N"]
# p_ovary_df = ovary_df[ovary_df["Label"] == "N"]
# p_testis_df = testis_df[testis_df["Label"] == "N"]

# %%
#tried doing N or U and P instead of just P
# p_heart_df = heart_df[(heart_df["Label"] == "U") | (heart_df["Label"] == "P")]
# p_breast_df = breast_df[(breast_df["Label"] == "U") | (breast_df["Label"] == "P")]
# p_lung_df = lung_df[(lung_df["Label"] == "U") | (lung_df["Label"] == "P")]
# p_muscle_df = muscle_df[(muscle_df["Label"] == "U") | (muscle_df["Label"] == "P")]
# p_ovary_df = ovary_df[(ovary_df["Label"] == "U") | (ovary_df["Label"] == "P")]
# p_testis_df = testis_df[(testis_df["Label"] == "U") | (testis_df["Label"] == "P")]

# %%
all_tis_p_labels_list = [p_heart_df, p_breast_df, p_lung_df, p_muscle_df, p_ovary_df, p_testis_df]

# %%
all_p_labels_df = pd.concat(all_tis_p_labels_list)
all_p_labels_df
# Out:
#      Tissue Description    ZScore      MeanExp   Breadth        CV  \
# 0     Heart        SDHA  1.993528   243.288498  0.846690  0.579540
# 1     Heart       TNNT2  3.955485  2449.070800  1.000000  0.458229
# 2     Heart       ACTN2  1.199822   507.696777  0.997677  0.604202
# 3     Heart       SCN5A  3.606891    38.107166  0.997677  0.631969
# 4     Heart        MYH6  3.016343  2784.512700  0.997677  1.017318
# ..      ...         ...       ...          ...       ...       ...
# 453   Ovary       STAG3  0.090064     6.457235  0.966667  0.497966
# 457  Testis       STK11  5.005595   118.628914  0.997230  0.225077
# 469  Testis          AR  0.327634     7.635316  0.952909  0.412031
# 473  Testis        PTEN -0.344879    21.242964  0.232687  0.201497
# 492  Testis       FGFR3 -0.120833    42.382297  1.000000  0.348168
#
#      NeighborMeanBreadth  NeighborMeanZscore Label  Probability  default_rank  \
# 0               0.264830           -0.377133     P     0.985383         179.0
# ...

# %%
#this is where i'm stuck right now. grr. also just having a hard time conceptually thinking about how this
#would work. right now in my head it just seems like i will always ends up with values up to 1.0. 
#but i guess the figure below alrayd disproves that because not every tissue has values from 0 to 1.0. hmm.
plt.figure(figsize=(15,9));
sns.boxplot( x=all_p_labels_df["Tissue"], y=all_p_labels_df["pct_rank"] )
# Out:
# <AxesSubplot:xlabel='Tissue', ylabel='pct_rank'>

# %%
#i knowwww this is notttt the way to doooo it !
select_values = all_p_labels_df['pct_rank'][(all_p_labels_df['pct_rank'] >= 0.6) & (all_p_labels_df['pct_rank'] <= 0.75)]

# %%
plt.figure(figsize=(15,9));
sns.boxplot( x=all_p_labels_df["Tissue"], y=select_values)
# Out:
# <AxesSubplot:xlabel='Tissue', ylabel='pct_rank'>

# %%
plt.figure(figsize=(3,5));
sns.boxplot( x=breast_df["Tissue"], y=breast_df["pct_rank"] )
# Out:
# <AxesSubplot:xlabel='Tissue', ylabel='pct_rank'>

# %%
new_try_heart_df = pd.read_csv("../data/new_copy.csv")

# %%
new_try_heart_df
# Out:
#     Tissue Description    ZScore      MeanExp   Breadth        CV  \
# 0    Heart        SDHA  1.993528   243.288498  0.846690  0.579540
# 1    Heart       TNNT2  3.955485  2449.070800  1.000000  0.458229
# 2    Heart       ACTN2  1.199822   507.696777  0.997677  0.604202
# 3    Heart       SCN5A  3.606891    38.107166  0.997677  0.631969
# 4    Heart        MYH6  3.016343  2784.512700  0.997677  1.017318
# ..     ...         ...       ...          ...       ...       ...
# 994    NaN         NaN       NaN          NaN       NaN       NaN
# 995    NaN         NaN       NaN          NaN       NaN       NaN
# 996    NaN         NaN       NaN          NaN       NaN       NaN
# 997    NaN         NaN       NaN          NaN       NaN       NaN
# 998    NaN         NaN       NaN          NaN       NaN       NaN
#
#      NeighborMeanBreadth  NeighborMeanZscore Label  Probability  ...  \
# 0               0.264830           -0.377133     P     0.985383  ...
# ...

# %%
new_try_heart_df = new_try_heart_df[["Tissue", "Description", "ZScore", "MeanExp", "Breadth", 
                        "CV", "NeighborMeanBreadth", "NeighborMeanZscore", "Label", "Probability"]]

# %%
new_try_heart_df = new_try_heart_df.dropna()

# %%
new_try_heart_df
# Out:
#     Tissue Description    ZScore      MeanExp   Breadth        CV  \
# 0    Heart        SDHA  1.993528   243.288498  0.846690  0.579540
# 1    Heart       TNNT2  3.955485  2449.070800  1.000000  0.458229
# 2    Heart       ACTN2  1.199822   507.696777  0.997677  0.604202
# 3    Heart       SCN5A  3.606891    38.107166  0.997677  0.631969
# 4    Heart        MYH6  3.016343  2784.512700  0.997677  1.017318
# ..     ...         ...       ...          ...       ...       ...
# 174  Heart       CENPF -0.264521     0.177311  0.091754  2.474792
# 175  Heart       SCN3B -0.379961     0.736151  0.041812  0.754590
# 176  Heart       KCNE2 -0.129869     0.256806  0.070848  1.264871
# 177  Heart      SLC6A2 -0.306395     0.009481  0.046458  2.197773
# 178  Heart        EGFR -0.841011     4.491855  0.003484  0.577752
#
#      NeighborMeanBreadth  NeighborMeanZscore Label  Probability
# 0               0.264830           -0.377133     P     0.985383
# ...

# %%
new_try_heart_df['default_rank'] = new_try_heart_df['Probability'].rank()
new_try_heart_df['max_rank'] = new_try_heart_df['Probability'].rank(method='max')
new_try_heart_df['NA_bottom'] = new_try_heart_df['Probability'].rank(na_option='bottom')
new_try_heart_df['pct_rank'] = new_try_heart_df['Probability'].rank(pct=True)

# %%
new_try_heart_df
# Out:
#     Tissue Description    ZScore      MeanExp   Breadth        CV  \
# 0    Heart        SDHA  1.993528   243.288498  0.846690  0.579540
# 1    Heart       TNNT2  3.955485  2449.070800  1.000000  0.458229
# 2    Heart       ACTN2  1.199822   507.696777  0.997677  0.604202
# 3    Heart       SCN5A  3.606891    38.107166  0.997677  0.631969
# 4    Heart        MYH6  3.016343  2784.512700  0.997677  1.017318
# ..     ...         ...       ...          ...       ...       ...
# 174  Heart       CENPF -0.264521     0.177311  0.091754  2.474792
# 175  Heart       SCN3B -0.379961     0.736151  0.041812  0.754590
# 176  Heart       KCNE2 -0.129869     0.256806  0.070848  1.264871
# 177  Heart      SLC6A2 -0.306395     0.009481  0.046458  2.197773
# 178  Heart        EGFR -0.841011     4.491855  0.003484  0.577752
#
#      NeighborMeanBreadth  NeighborMeanZscore Label  Probability  default_rank  \
# 0               0.264830           -0.377133     P     0.985383         179.0
# ...

# %%
plt.figure(figsize=(3,5));
sns.boxplot( x=new_try_heart_df["Tissue"], y=new_try_heart_df["pct_rank"] );

# %% [markdown]
# do i need to do bootstrapping thing? so ill take 80% of the genes, find the mean of their percent ranks, and do this a bunch of times to end up with a bunch of mean pct ranks?

# %%
import random
my_set = set(fig_3_data["Probability"])
print(len(my_set))
len(random.sample(my_set, k=round(len(my_set) * 0.8)))
# Out:
# 500
# 400

# %%
#NO LONGER IN USE
#maybe nested for loop? or for loop in a while loop?
# iterations = 10
# all_mpr = 0
# for i in range(iterations):
#     #num_genes = 0.8*len(column for tissue im on)
#     #take random 80% of the genes
#     gene_vals = 0
#     #gene_vals += pct rank for each gene (loop might be nice here)
#     mean_pct_rank = gene_vals/num_genes
#     all_mpr += mean_pct_rank
    
#print(all_mpr) #this is list of mean percent rank for each iteration, this would be my range that hopefully 
#is in the same range as the original paper. in formal report, mention that this seems like cheating?

# %%
#getting a bunch of mean pct ranks for heart tissue
heart_set = set(p_heart_df["pct_rank"])

iterations = 1000
all_mpr_heart = []
for i in range(iterations): 
    #take random 80% of the genes and find mean of their percent ranks
    mean_pct_rank = np.mean(random.sample(my_set, k=round(len(heart_set) * 0.8)))

    #now add this to list of mean percent ranks for this tissue
    all_mpr_heart.append(mean_pct_rank) 
    
print(all_mpr_heart[0:15])
# Out:
# [0.639046710410959, 0.6918963278082192, 0.6884115660273972, 0.6769390104109589, 0.6358049832876712, 0.636272361780822, 0.6834480839726028, 0.6514772794520548, 0.6436347894520548, 0.6801364910958905, 0.6468152330136986, 0.6398828891780822, 0.6211467631506848, 0.6270113673972603, 0.6659719069863014]

# %%
#getting a bunch of mean pct ranks for heart tissue
breast_set = set(p_breast_df["pct_rank"])

iterations = 1000
all_mpr_breast = []
for i in range(iterations): 
    #take random 80% of the genes and find mean of their percent ranks
    mean_pct_rank = np.mean(random.sample(breast_set, k=round(len(breast_set) * 0.8)))

    #now add this to list of mean percent ranks for this tissue
    all_mpr_breast.append(mean_pct_rank) 
    
#print(all_mpr_breast[10:30])

# %%
#getting a bunch of mean pct ranks for heart tissue
lung_set = set(p_lung_df["pct_rank"])

iterations = 1000
all_mpr_lung = []
for i in range(iterations): 
    #take random 80% of the genes and find mean of their percent ranks
    mean_pct_rank = np.mean(random.sample(my_set, k=round(len(lung_set) * 0.8)))

    #now add this to list of mean percent ranks for this tissue
    all_mpr_lung.append(mean_pct_rank) 
    
#print(all_mpr_lung)

# %%
muscle_set = set(p_muscle_df["pct_rank"])

iterations = 1000
all_mpr_muscle = []
for i in range(iterations): 
    #take random 80% of the genes and find mean of their percent ranks
    mean_pct_rank = np.mean(random.sample(my_set, k=round(len(muscle_set) * 0.8)))

    #now add this to list of mean percent ranks for this tissue
    all_mpr_muscle.append(mean_pct_rank) 
    

#print(all_mpr_muscle)

# %%
#getting a bunch of mean pct ranks for heart tissue
ovary_set = set(p_ovary_df["pct_rank"])

iterations = 1000
all_mpr_ovary = []
for i in range(iterations): 
    #take random 80% of the genes and find mean of their percent ranks
    mean_pct_rank = np.mean(random.sample(my_set, k=round(len(ovary_set) * 0.8)))

    #now add this to list of mean percent ranks for this tissue
    all_mpr_ovary.append(mean_pct_rank) 
    
#print(all_mpr_ovary)

# %%
#getting a bunch of mean pct ranks for heart tissue
testis_set = set(p_testis_df["pct_rank"])

iterations = 1000
all_mpr_testis = []
for i in range(iterations): 
    #take random 80% of the genes and find mean of their percent ranks
    mean_pct_rank = np.mean(random.sample(my_set, k=round(len(testis_set) * 0.8)))

    #now add this to list of mean percent ranks for this tissue
    all_mpr_testis.append(mean_pct_rank) 
    
#print(all_mpr_testis)

# %%
all_tissues_mpr_list = [all_mpr_heart, all_mpr_breast, all_mpr_lung, all_mpr_muscle, all_mpr_ovary, all_mpr_testis]

# %%
flat_list = []
for sublist in all_tissues_mpr_list:
    for item in sublist:
        flat_list.append(item)

# %%
tissue_col = []
for i in range(1000):
    tissue_col.append("Heart")
    
for i in range(1000):
    tissue_col.append("Breast")
    
for i in range(1000):
    tissue_col.append("Lung")
    
for i in range(1000):
    tissue_col.append("Muscle")
    
for i in range(1000):
    tissue_col.append("Ovary")
    
for i in range(1000):
    tissue_col.append("Tesis")

# %%
len(tissue_col)
# Out:
# 6000

# %%
d = {"Tissue" : tissue_col, "Mean Percent Rank" : flat_list}
all_tissues_mpr_df = pd.DataFrame(data=d)

# %%
all_tissues_mpr_df
# Out:
#      Tissue  Mean Percent Rank
# 0     Heart           0.639047
# 1     Heart           0.691896
# 2     Heart           0.688412
# 3     Heart           0.676939
# 4     Heart           0.635805
# ...     ...                ...
# 5995  Tesis           0.784032
# 5996  Tesis           0.595130
# 5997  Tesis           0.718943
# 5998  Tesis           0.689561
# 5999  Tesis           0.717496
#
# [6000 rows x 2 columns]

# %%
plt.figure(figsize=(13,10));
sns.boxplot( x=all_tissues_mpr_df["Tissue"], y=all_tissues_mpr_df["Mean Percent Rank"] )
x = [-2, 7]
y = [0.5, 0.5]
plt.plot(x, y, c="black", linewidth=3)
plt.xlim(-0.5, 5.5)
plt.ylim(0.45, 0.9);
